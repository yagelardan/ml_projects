# %%
from sklearn.datasets import fetch_olivetti_faces

# %%
dataset = fetch_olivetti_faces(shuffle=True)
X = dataset.data
y = dataset.target

# %%
n_samples, n_features = X.shape
print(n_samples, n_features)
# Out:
# 400 4096

# %%
X.shape
# Out:
# (400, 4096)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

def plot_face(face):
    fig = plt.figure()
    face = face.reshape(64,64)
    plt.imshow(face)
    plt.show()
print("5 first faces:")
for i in range(0,5):
    print("index: ",i)
    plot_face(X[i])
# Out:
# 5 first faces:
# index:  0
# <img src="data:image/png;base64,..." width="640">
# index:  1
# <img src="data:image/png;base64,..." width="640">
# index:  2
# <img src="data:image/png;base64,..." width="640">
# index:  3
# <img src="data:image/png;base64,..." width="640">
# index:  4
# <img src="data:image/png;base64,..." width="640">

# %%
#Recuce dimensionals using pca
from sklearn.decomposition import PCA 
pca = PCA(n_components=0.99)
X_pca = pca.fit_transform(X) #for one digit
X_pca.shape
# Out:
# (400, 260)

# %%
print("Inverse dimensional reduced image using pca:")
plot_face(pca.inverse_transform(X_pca[0]))
# Out:
# Inverse dimensional reduced image using pca:
# /home/yagel/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,..." width="640">

# %%
'''
#tsne to 3d
from sklearn.manifold import TSNE

X_tsne_2d = TSNE(n_components=2).fit_transform(X_pca)#for all digits
X_tsne_2d.shape
'''
# Out:
# '\n#tsne to 3d\nfrom sklearn.manifold import TSNE\n\nX_tsne_2d = TSNE(n_components=2).fit_transform(X_pca)#for all digits\nX_tsne_2d.shape\n'

# %%
'''
fig = plt.figure()
colrs = ["red", "green", "black","blue", "grey","brown","purple","orange","c","yellow"]
for i in range (0,10):
    #plt.scatter(X_tsne_3d[y == i,0], X_tsne_3d[y == i,1] ,X_tsne_3d[y == i,2] , label = i, color=[i], alpha=0.5)
    plt.scatter(X_tsne_3d[y == i,0], X_tsne_3d[y == i,1] ,color=colrs[i] ,label = i, alpha=0.5)
plt.title("PCA to T-sne 2D DOESNT give good clustering:")
plt.legend()
plt.show()
'''
# Out:
# '\nfig = plt.figure()\ncolrs = ["red", "green", "black","blue", "grey","brown","purple","orange","c","yellow"]\nfor i in range (0,10):\n    #plt.scatter(X_tsne_3d[y == i,0], X_tsne_3d[y == i,1] ,X_tsne_3d[y == i,2] , label = i, color=[i], alpha=0.5)\n    plt.scatter(X_tsne_3d[y == i,0], X_tsne_3d[y == i,1] ,color=colrs[i] ,label = i, alpha=0.5)\nplt.title("PCA to T-sne 2D DOESNT give good clustering:")\nplt.legend()\nplt.show()\n'

# %%
'''
#tsne to 3d
X_tsne_3d = TSNE(n_components=3).fit_transform(X_pca)#for all digits
X_tsne_3d.shape
'''
# Out:
# '\n#tsne to 3d\nX_tsne_3d = TSNE(n_components=3).fit_transform(X_pca)#for all digits\nX_tsne_3d.shape\n'

# %%
'''
# %matplotlib notebook
from mpl_toolkits.mplot3d import axes3d
import matplotlib as mpl

fig = plt.figure()
ax1 = fig.add_subplot(111, projection="3d")
colrs = ["red", "green", "black","blue", "grey","brown","purple","orange","c","yellow"]

for i in range (0,10):
    #plt.scatter(X_tsne_3d[y == i,0], X_tsne_3d[y == i,1] ,X_tsne_3d[y == i,2] , label = i, color=[i], alpha=0.5)
    plt.scatter(X_tsne_3d[y == i,0], X_tsne_3d[y == i,1] ,X_tsne_3d[y == i,2],color=colrs[i] ,label = i, alpha=0.5)
plt.title("PCA to T-sne 3D DOESNT give good clustering:")
plt.legend()
plt.show()
'''
# Out:
# '\n%matplotlib notebook\nfrom mpl_toolkits.mplot3d import axes3d\nimport matplotlib as mpl\n\nfig = plt.figure()\nax1 = fig.add_subplot(111, projection="3d")\ncolrs = ["red", "green", "black","blue", "grey","brown","purple","orange","c","yellow"]\n\nfor i in range (0,10):\n    #plt.scatter(X_tsne_3d[y == i,0], X_tsne_3d[y == i,1] ,X_tsne_3d[y == i,2] , label = i, color=[i], alpha=0.5)\n    plt.scatter(X_tsne_3d[y == i,0], X_tsne_3d[y == i,1] ,X_tsne_3d[y == i,2],color=colrs[i] ,label = i, alpha=0.5)\nplt.title("PCA to T-sne 3D DOESNT give good clustering:")\nplt.legend()\nplt.show()\n'

# %%
# K-means for X_pca, with 40 centroids 
from sklearn.cluster import KMeans
k = 40
kmeans = KMeans(n_clusters=k)
y_pred = kmeans.fit_predict(X_pca)

# %%
y_pred[0:20]
# Out:
# array([15, 30, 34, 28, 33, 22, 31, 20,  3, 35,  3, 15,  5, 11, 24, 27, 39,
#         7, 16,  3], dtype=int32)

# %%
#for i in range(0,2):
#    plot_face(faces[i])
index = 0
faces_in_cluster=0
for label in y_pred:
    if(label == 34):
        print("index: ",index)
        plot_face(faces[index])
        faces_in_cluster+=1
    index+=1
print("number of faces in cluster: ", faces_in_cluster)
# Out:
# index:  2
# <img src="data:image/png;base64,..." width="640">
# index:  105
# <img src="data:image/png;base64,..." width="640">
# index:  119
# <img src="data:image/png;base64,..." width="640">
# index:  272
# <img src="data:image/png;base64,..." width="640">
# index:  328
# <img src="data:image/png;base64,..." width="640">
# index:  346
# <img src="data:image/png;base64,..." width="640">
# number of faces in cluster:  6
